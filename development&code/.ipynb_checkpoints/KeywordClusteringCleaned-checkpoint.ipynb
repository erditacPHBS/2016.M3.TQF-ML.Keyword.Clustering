# %%
# import pandas library to read data from files and to create data frames
import pandas as pd

# read the entitiy-article relationship data from csv file to a dataframe
entityRel = pd.read_csv('data_files/entityRelSmallX2.csv',sep=';')

# print the column names and the dataframe dimensions
print(entityRel.columns)
print(entityRel.shape)
# Out:
# Index([u'id', u'relevance', u'date_added', u'article_id', u'entity_id'], dtype='object')
# (262, 5)

# %%
# Get rid of the keyword-article relations that has 0 relevance.
# We do that because 0 relevance means we're not sure at all whether that keyword has a relationship with the keyword or not

entityRelNotZero = entityRel[entityRel['relevance'] > 0]

# %%
keywordsList = []

# We have 10 different article for the current data so we will run a for loop 908 times

for num in range(1, 11):
    # This is how we will get the keywords from the same article
    similarKeywords = entityRelNotZero[entityRelNotZero['article_id'] == num]

    # create a link between all keyword from the same article
    for x in range(1, similarKeywords.shape[0]):
        keywordsList.append({'source': similarKeywords.iloc[0]['entity_id'], 'target': similarKeywords.iloc[x]['entity_id'], 'value': int(similarKeywords.iloc[0]['relevance']*similarKeywords.iloc[x]['relevance']*100)})

# %%
keywordsList
# Out:
# [{'source': 1013, 'target': 1014, 'value': 4},
#  {'source': 1013, 'target': 1015, 'value': 4},
#  {'source': 1013, 'target': 119, 'value': 4},
#  {'source': 1013, 'target': 1016, 'value': 4},
#  {'source': 1013, 'target': 1017, 'value': 4},
#  {'source': 1013, 'target': 1018, 'value': 4},
#  {'source': 1013, 'target': 1019, 'value': 4},
#  {'source': 1013, 'target': 1020, 'value': 4},
#  {'source': 1013, 'target': 1021, 'value': 4},
#  {'source': 1013, 'target': 1022, 'value': 4},
#  {'source': 1013, 'target': 1023, 'value': 4},
#  {'source': 1013, 'target': 1024, 'value': 4},
#  {'source': 1013, 'target': 1025, 'value': 4},
#  {'source': 3629, 'target': 385, 'value': 4},
#  {'source': 3629, 'target': 328, 'value': 4},
#  {'source': 3629, 'target': 3089, 'value': 4},
#  {'source': 3629, 'target': 3630, 'value': 4},
#  {'source': 3629, 'target': 2960, 'value': 4},
#  {'source': 3629, 'target': 1960, 'value': 4},
#  {'source': 3629, 'target': 3631, 'value': 4},
#  {'source': 3629, 'target': 1497, 'value': 4},
#  {'source': 3629, 'target': 3632, 'value': 4},
#  {'source': 3629, 'target': 549, 'value': 16},
#  {'source': 3629, 'target': 3633, 'value': 4},
#  {'source': 3629, 'target': 325, 'value': 4},
#  {'source': 3629, 'target': 3045, 'value': 4},
#  {'source': 3629, 'target': 3524, 'value': 4},
#  {'source': 3629, 'target': 1623, 'value': 4},
#  {'source': 3629, 'target': 479, 'value': 4},
#  {'source': 3629, 'target': 285, 'value': 4},
#  {'source': 3629, 'target': 3634, 'value': 4},
#  {'source': 3629, 'target': 1660, 'value': 4},
#  {'source': 3629, 'target': 699, 'value': 4},
#  {'source': 3629, 'target': 3635, 'value': 4},
#  {'source': 3629, 'target': 17, 'value': 4},
#  {'source': 3629, 'target': 3636, 'value': 4},
#  {'source': 3629, 'target': 2095, 'value': 4},
#  {'source': 3629, 'target': 142, 'value': 4},
#  {'source': 1823, 'target': 2922, 'value': 4},
#  {'source': 1823, 'target': 4285, 'value': 4},
#  {'source': 1823, 'target': 4397, 'value': 4},
#  {'source': 1823, 'target': 4398, 'value': 4},
#  {'source': 1823, 'target': 4399, 'value': 4},
#  {'source': 1823, 'target': 385, 'value': 4},
#  {'source': 1823, 'target': 438, 'value': 4},
#  {'source': 1823, 'target': 4400, 'value': 4},
#  {'source': 1823, 'target': 2143, 'value': 4},
#  {'source': 1823, 'target': 913, 'value': 4},
#  {'source': 1823, 'target': 4335, 'value': 4},
#  {'source': 1823, 'target': 916, 'value': 4},
#  {'source': 1823, 'target': 250, 'value': 4},
#  {'source': 1823, 'target': 942, 'value': 4},
#  {'source': 1823, 'target': 142, 'value': 4},
#  {'source': 1823, 'target': 4401, 'value': 4},
#  {'source': 1823, 'target': 536, 'value': 4},
#  {'source': 487, 'target': 159, 'value': 4},
#  {'source': 487, 'target': 4493, 'value': 4},
#  {'source': 487, 'target': 2777, 'value': 16},
#  {'source': 487, 'target': 1454, 'value': 4},
#  {'source': 487, 'target': 14, 'value': 4},
#  {'source': 487, 'target': 4494, 'value': 4},
#  {'source': 487, 'target': 451, 'value': 4},
#  {'source': 487, 'target': 1456, 'value': 4},
#  {'source': 487, 'target': 119, 'value': 4},
#  {'source': 487, 'target': 1660, 'value': 4},
#  {'source': 487, 'target': 1575, 'value': 4},
#  {'source': 487, 'target': 3913, 'value': 4},
#  {'source': 487, 'target': 1811, 'value': 4},
#  {'source': 487, 'target': 458, 'value': 4},
#  {'source': 487, 'target': 1580, 'value': 4},
#  {'source': 487, 'target': 3759, 'value': 4},
#  {'source': 487, 'target': 4495, 'value': 4},
#  {'source': 487, 'target': 4496, 'value': 4},
#  {'source': 5435, 'target': 5436, 'value': 4},
#  {'source': 5435, 'target': 3338, 'value': 4},
#  {'source': 5435, 'target': 698, 'value': 4},
#  {'source': 5435, 'target': 5437, 'value': 16},
#  {'source': 5435, 'target': 438, 'value': 4},
#  {'source': 5435, 'target': 1766, 'value': 4},
#  {'source': 5435, 'target': 119, 'value': 4},
#  {'source': 5435, 'target': 17, 'value': 4},
#  {'source': 5435, 'target': 3333, 'value': 4},
#  {'source': 5435, 'target': 5438, 'value': 4},
#  {'source': 5435, 'target': 417, 'value': 4},
#  {'source': 5435, 'target': 5439, 'value': 4},
#  {'source': 5435, 'target': 5440, 'value': 4},
#  {'source': 5435, 'target': 5441, 'value': 4},
#  {'source': 5435, 'target': 4868, 'value': 4},
#  {'source': 5435, 'target': 5442, 'value': 4},
#  {'source': 5435, 'target': 3452, 'value': 4},
#  {'source': 5435, 'target': 5443, 'value': 4},
#  {'source': 5435, 'target': 5444, 'value': 16},
#  {'source': 5445, 'target': 5446, 'value': 4},
#  {'source': 5445, 'target': 5447, 'value': 4},
#  {'source': 5445, 'target': 119, 'value': 4},
#  {'source': 5445, 'target': 136, 'value': 4},
#  {'source': 5445, 'target': 17, 'value': 4},
#  {'source': 5445, 'target': 554, 'value': 4},
#  {'source': 5445, 'target': 146, 'value': 16},
#  {'source': 5445, 'target': 417, 'value': 16},
#  {'source': 5445, 'target': 1888, 'value': 4},
#  {'source': 5445, 'target': 5448, 'value': 4},
#  {'source': 5445, 'target': 5449, 'value': 4},
#  {'source': 5445, 'target': 5450, 'value': 4},
#  {'source': 5445, 'target': 5451, 'value': 4},
#  {'source': 5445, 'target': 129, 'value': 4},
#  {'source': 5445, 'target': 1866, 'value': 4},
#  {'source': 5445, 'target': 5452, 'value': 4},
#  {'source': 5445, 'target': 2913, 'value': 4},
#  {'source': 5445, 'target': 5453, 'value': 4},
#  {'source': 1487, 'target': 1574, 'value': 4},
#  {'source': 1487, 'target': 438, 'value': 4},
#  {'source': 1487, 'target': 1575, 'value': 4},
#  {'source': 1487, 'target': 1576, 'value': 4},
#  {'source': 1487, 'target': 1134, 'value': 4},
#  {'source': 1487, 'target': 697, 'value': 4},
#  {'source': 1487, 'target': 1490, 'value': 4},
#  {'source': 1487, 'target': 1491, 'value': 4},
#  {'source': 1487, 'target': 285, 'value': 16},
#  {'source': 1487, 'target': 1577, 'value': 4},
#  {'source': 1487, 'target': 428, 'value': 4},
#  {'source': 1487, 'target': 361, 'value': 4},
#  {'source': 1487, 'target': 1488, 'value': 4},
#  {'source': 1487, 'target': 1548, 'value': 10},
#  {'source': 1487, 'target': 1578, 'value': 16},
#  {'source': 1487, 'target': 1579, 'value': 4},
#  {'source': 1487, 'target': 1580, 'value': 4},
#  {'source': 1487, 'target': 1581, 'value': 4},
#  {'source': 1487, 'target': 1468, 'value': 16},
#  {'source': 1487, 'target': 1582, 'value': 4},
#  {'source': 1487, 'target': 639, 'value': 4},
#  {'source': 1487, 'target': 266, 'value': 4},
#  {'source': 1176, 'target': 7233, 'value': 4},
#  {'source': 1176, 'target': 7234, 'value': 4},
#  {'source': 1176, 'target': 7235, 'value': 4},
#  {'source': 1176, 'target': 7236, 'value': 4},
#  {'source': 1176, 'target': 1560, 'value': 4},
#  {'source': 1176, 'target': 17, 'value': 4},
#  {'source': 1176, 'target': 7237, 'value': 4},
#  {'source': 1176, 'target': 7238, 'value': 4},
#  {'source': 1176, 'target': 7239, 'value': 4},
#  {'source': 1176, 'target': 1575, 'value': 16},
#  {'source': 1176, 'target': 142, 'value': 4},
#  {'source': 1176, 'target': 7240, 'value': 4},
#  {'source': 1176, 'target': 7241, 'value': 4},
#  {'source': 1176, 'target': 7242, 'value': 4},
#  {'source': 1176, 'target': 7243, 'value': 4},
#  {'source': 1176, 'target': 713, 'value': 4},
#  {'source': 1176, 'target': 277, 'value': 4},
#  {'source': 1176, 'target': 7244, 'value': 4},
#  {'source': 1176, 'target': 1580, 'value': 4},
#  {'source': 1176, 'target': 7245, 'value': 4},
#  {'source': 1176, 'target': 7246, 'value': 4},
#  {'source': 1176, 'target': 464, 'value': 4},
#  {'source': 1176, 'target': 7247, 'value': 4},
#  {'source': 1176, 'target': 7248, 'value': 4},
#  {'source': 1176, 'target': 1639, 'value': 4},
#  {'source': 607, 'target': 1765, 'value': 4},
#  {'source': 607, 'target': 1490, 'value': 4},
#  {'source': 607, 'target': 285, 'value': 4},
#  {'source': 607, 'target': 708, 'value': 4},
#  {'source': 607, 'target': 1766, 'value': 4},
#  {'source': 607, 'target': 480, 'value': 4},
#  {'source': 607, 'target': 6, 'value': 4},
#  {'source': 607, 'target': 1767, 'value': 4},
#  {'source': 607, 'target': 578, 'value': 4},
#  {'source': 607, 'target': 266, 'value': 16},
#  {'source': 1765, 'target': 1713, 'value': 4},
#  {'source': 1765, 'target': 1850, 'value': 4},
#  {'source': 1765, 'target': 1490, 'value': 4},
#  {'source': 1765, 'target': 1491, 'value': 4},
#  {'source': 1765, 'target': 285, 'value': 16},
#  {'source': 1765, 'target': 708, 'value': 4},
#  {'source': 1765, 'target': 1766, 'value': 4},
#  {'source': 1765, 'target': 480, 'value': 4},
#  {'source': 1765, 'target': 1717, 'value': 4},
#  {'source': 1765, 'target': 1767, 'value': 4},
#  {'source': 1765, 'target': 6, 'value': 4},
#  {'source': 1765, 'target': 1714, 'value': 4},
#  {'source': 1765, 'target': 1562, 'value': 4},
#  {'source': 1765, 'target': 578, 'value': 4},
#  {'source': 1765, 'target': 1851, 'value': 4},
#  {'source': 1765, 'target': 266, 'value': 16}]

# %%
keywordsLinksCSV = open('data_files/keywordsLinksSmallClean.csv', 'w')

keywordsLinksCSV.write('"source";"target";"value"\n')
for item in keywordsList:
    keywordsLinksCSV.write(str(item['source']) + ';' + str(item['target']) + ';' + str(item['value']) + '\n')

# %%
# read the csv for links between keywords
linksBetweenKeywords = pd.read_csv('data_files/keywordsLinksSmallClean.csv',sep=';')

# print the column names and the dataframe dimensions
print(linksBetweenKeywords.columns)
print(linksBetweenKeywords.shape)
# Out:
# ---------------------------------------------------------------------------
# EmptyDataError                            Traceback (most recent call last)
# <ipython-input-6-8aabfb408418> in <module>()
#       1 # read the csv for links between keywords
# ----> 2 linksBetweenKeywords = pd.read_csv('data_files/keywordsLinksSmallClean.csv',sep=';')
#       3
#       4 # print the column names and the dataframe dimensions
#       5 print(linksBetweenKeywords.columns)
#
# C:\ProgramData\Anaconda2\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, skip_footer, doublequote, delim_whitespace, as_recarray, compact_ints, use_unsigned, low_memory, buffer_lines, memory_map, float_precision)
#     644                     skip_blank_lines=skip_blank_lines)
#     645
# --> 646         return _read(filepath_or_buffer, kwds)
#     647
#     648     parser_f.__name__ = name
#
# C:\ProgramData\Anaconda2\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     387
#     388     # Create the parser.
# --> 389     parser = TextFileReader(filepath_or_buffer, **kwds)
#     390
#     391     if (nrows is not None) and (chunksize is not None):
#
# C:\ProgramData\Anaconda2\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     728             self.options['has_index_names'] = kwds['has_index_names']
#     729
# --> 730         self._make_engine(self.engine)
#     731
#     732     def close(self):
#
# C:\ProgramData\Anaconda2\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#     921     def _make_engine(self, engine='c'):
#     922         if engine == 'c':
# --> 923             self._engine = CParserWrapper(self.f, **self.options)
#     924         else:
#     925             if engine == 'python':
#
# C:\ProgramData\Anaconda2\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1388         kwds['allow_leading_cols'] = self.index_col is not False
#    1389
# -> 1390         self._reader = _parser.TextReader(src, **kwds)
#    1391
#    1392         # XXX
#
# pandas\parser.pyx in pandas.parser.TextReader.__cinit__ (pandas\parser.c:6171)()
#
# EmptyDataError: No columns to parse from file

# %%
linksBetweenKeywords.iloc[367]

# %%
# create keyword nodes
# different articles may include same keywords
# we need to be sure that we don't repeat the same keyword as node
# so we use sets to add keywords
keywordNodes = set([])
for x in range(0, entityRelNotZero.shape[0]):
    keywordNodes.add(entityRelNotZero.iloc[x]['entity_id'])

# %%
# Create JSON file for nodes and links
keywordsLinksJSON = open('data_files/keywordsLinksSmallClean.json', 'w')

# Add nodes to json file
keywordsLinksJSON.write('{\n')
keywordsLinksJSON.write('"nodes":[\n')

for node in keywordNodes:
    keywordsLinksJSON.write('{"id": ' + str(node) + ', "group": ' + str(1) + '},\n')

keywordsLinksJSON.write('],\n')
keywordsLinksJSON.write('"links": [\n')

for item in keywordsList:
    keywordsLinksJSON.write('{"source": ' + str(item['source']) + ', "target": ' + str(item['target']) + ', "value": ' + str(item['value']) + '},\n')

keywordsLinksJSON.write(']\n')
keywordsLinksJSON.write('}\n')
